# %% [markdown]
# <a href="https://colab.research.google.com/github/hikone7299/gazo/blob/master/learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/My Drive/ColabData')

import ic_module as ic

import importlib
importlib.reload(ic)

# 関数実行
ic.Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9)
# Out:
# >> 学習サンプル数 :  (536, 32, 32, 3)
# >> 学習開始
# Epoch 1/50
# 55/56 [============================>.] - ETA: 0s - loss: 1.0272 - accuracy: 0.4614
# Epoch 00001: val_loss improved from inf to 1.10163, saving model to best.hdf5
# 56/56 [==============================] - 3s 60ms/step - loss: 1.0275 - accuracy: 0.4596 - val_loss: 1.1016 - val_accuracy: 0.3000
# Epoch 2/50
# 55/56 [============================>.] - ETA: 0s - loss: 1.0052 - accuracy: 0.4886
# Epoch 00002: val_loss did not improve from 1.10163
# 56/56 [==============================] - 3s 57ms/step - loss: 1.0090 - accuracy: 0.4888 - val_loss: 1.2125 - val_accuracy: 0.3556
# Epoch 3/50
# 55/56 [============================>.] - ETA: 0s - loss: 0.9543 - accuracy: 0.6182
# Epoch 00003: val_loss did not improve from 1.10163
# 56/56 [==============================] - 3s 57ms/step - loss: 0.9527 - accuracy: 0.6211 - val_loss: 1.2226 - val_accuracy: 0.3667
# Epoch 4/50
# ...
